# %% [markdown]
# <a href="https://colab.research.google.com/github/Kartikee12/DAV/blob/main/Exp1_DAV_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Experiment-1**
#
# ### **Aim :**  Getting introduced to data analytics libraries in Python and R.
#
# ### **Lab Objectives :** To effectively use libraries for data analytics.
#
# ### **Lab Outcomes (LO) :** Explore various data analytics Libraries in R and Python. (LO1)
#
# ### **Task to be performed :**
# 1.   Explore Top-5 Data Analytics Libraries in Python (w.r.t Features & Applications) :-
#  1.   **NumPy :** NumPy is a fundamental library for numerical computing in Python, providing a powerful N-dimensional array object that is essential for various scientific and data analysis tasks. Here are some key features and applications of NumPy:
#
#       *   Features:
#            1.   Provides fast, precompiled functions for numerical routines.
#            2.   Array-oriented computing for better efficiency.
#            3.   Supports an object-oriented approach.
#            4.   Compact and faster computations with vectorization.
#
#       *   Applications:
#            1.   Extensively used in data analysis.
#            2.   Creates powerful N-dimensional array.
#            3.   Forms the base of other libraries, such as SciPy and scikit-learn.
#            4.   Replacement of MATLAB when used with SciPy and matplotlib.
#
#  2.   **Pandas :** Pandas, also known as Python Data Analysis, is a cornerstone in the data science life cycle, recognized as one of the most widely used Python libraries. With a substantial presence on GitHub, boasting over 17,000 comments and a vibrant community of 1,200 contributors, Pandas is heavily relied upon for data analysis and cleaning tasks. Here are some key features and applications of Pandas:
#
#       *   Features:
#            1.   Eloquent syntax and rich functionalities that gives you the freedom to deal with missing data.
#            2.   Enables you to create your own function and run it across a series of data.
#            3.   High-level abstraction.
#            4.   Contains high-level data structures and manipulation tools.
#
#       *   Applications:
#            1.   General data wrangling and data cleaning.
#            2.   ETL (extract, transform, load) jobs for data transformation and data storage, as it has excellent support for loading CSV files into its data frame format.
#            3.   Used in a variety of academic and commercial areas, including statistics, finance and neuroscience.
#            4.   Time-series-specific functionality, such as date range generation, moving window, linear regression and date shifting.
#
#  3.   **SciPy :** SciPy, short for Scientific Python, is a prominent free and open-source Python library specifically designed for high-level scientific computations. With an impressive presence on GitHub, accumulating around 19,000 comments, and a dynamic community comprising about 600 contributors, SciPy is extensively utilized for its contributions to scientific and technical computations. Here are some key features and applications of SciPy:
#
#       *   Features:
#            1.   Collection of algorithms and functions built on the NumPy extension of Python.
#            2.   High-level commands for data manipulation and visualization.
#            3.   Multidimensional image processing with the SciPy ndimage submodule.
#            4.   Includes built-in functions for solving differential equations.
#
#       *   Applications:
#            1.   Multidimensional image operations.
#            2.   Solving differential equations and the Fourier transform.
#            3.   Optimization algorithms.
#            4.   Linear algebra.
#
#  4.   **Matplotlib :** Matplotlib is a powerful and aesthetically pleasing plotting library for Python. With approximately 26,000 comments on GitHub and a vibrant community of around 700 contributors, Matplotlib is a widely adopted tool for creating various types of visualizations. Its primary focus is on producing high-quality graphs and plots, making it a go-to library for data visualization tasks. Matplotlib also provides an object-oriented API, allowing users to embed plots into applications seamlessly. Here are some key features and applications of Matplotlib:
#
#       *   Features:
#            1.   Usable as a MATLAB replacement, with the advantage of being free and open source .
#            2.   Supports dozens of backends and output types, which means you can use it regardless of which operating system you’re using or which output format you wish to use.
#            3.   Pandas itself can be used as wrappers around MATLAB API to drive MATLAB like a cleaner.
#            4.   Low memory consumption and better runtime behavior.
#
#       *   Applications:
#            1.   Correlation analysis of variables.
#            2.   Visualize 95 percent confidence intervals of the models.
#            3.   Outlier detection using a scatter plot etc.
#            4.   Visualize the distribution of data to gain instant insights.
#
#  5.   **TensorFlow :** TensorFlow stands as the first in the list of Python libraries for data science, known for its prowess in high-performance numerical computations. With an impressive presence on GitHub, boasting around 35,000 comments, and a dynamic community of approximately 1,500 contributors, TensorFlow is widely utilized across various scientific fields. It serves as a comprehensive framework for defining and executing computations involving tensors, which are essential computational objects. Here are some key features and applications of TensorFlow:
#
#       *   Features:
#            1.   Better computational graph visualizations.
#            2.   Reduces error by 50 to 60 percent in neural machine learning.
#            3.   Parallel computing to execute complex models.
#            4.   Seamless library management backed by Google.
#
#       *   Applications:
#            1.   Speech and image recognition.
#            2.   Text-based applications.
#            3.   Time-series analysis.
#            4.   Video detection.
#
# 2.   Explore Top-5 Data Analytics Libraries in R (w.r.t Features & Applications):-
#  1.   **Dplyr :** Dplyr is a widely-used R package designed for efficient and intuitive data manipulation. The package revolves around five key functions that form the backbone of most data manipulation tasks. Whether working with local data frames or remote database tables, Dplyr provides a streamlined and consistent syntax for manipulating data efficiently. Here are some key features and applications of Dplyr:
#
#       *   Features:
#            1.   Select: Enables column selection for focusing on specific variables in a dataset.
#            2.   Filter: Facilitates row filtering based on defined criteria, creating subsets of data.
#            3.   Arrange: Allows the arrangement of rows, providing control over the order of observations.
#            4.   Mutate: Supports the creation of new columns, enhancing the dataset with derived or modified variables.
#
#       *   Applications:
#            1.   Efficient data selection and transformation.
#            2.   Sorting and arranging data for analysis.
#            3.   Creating and manipulating columns in a dataset.
#            4.   Aggregating and summarizing information.
#
#  2.   **Ggplot2 :** Ggplot2 is the one of the best library for data visualization in R. The ggplot2 library implements a “grammar of graphics” (Wilkinson, 2005). This approach gives us a coherent way to produce visualizations by expressing relationships between the attributes of data and their graphical representation. Ggplot2 has wide range of functions. Here are some key features and applications of Ggplot2:
#
#       *   Features:
#            1.   Data Visualization: Recognized as one of the best libraries for data visualization in R.
#            2.   Wide Range of Functions: Offers a diverse set of functions for creating a variety of visualizations.
#            3.   Customization: Allows extensive customization of plots, including axes, labels, and themes.
#            4.   Scalability: Scalable for handling both simple and complex visualizations.
#
#       *   Applications:
#            1.   Data Exploration: Ideal for exploring and visualizing patterns and trends in data.
#            2.   Statistical Graphics: Widely used for creating statistical graphics and charts.
#            3.   Publication-Ready Visualizations: Produces high-quality visualizations suitable for publications and presentations.
#            4.   Comparative Analysis: Facilitates comparative analysis through layered visualizations.
#
#  3.   **Esquisse :** This package has brought the most important feature of Tableau to R. Just drag and drop, and get your visualization done in minutes. This is actually an enhancement to ggplot2. This addin allows you to interactively explore your data by visualizing it with the ggplot2 package. It allows you to draw bar graphs, curves, scatter plots, histograms, then export the graph or retrieve the code generating the graph. Here are some key features and applications Esquisse:
#
#       *   Features:
#            1.   Interactive Data Exploration: Enables interactive exploration of data through a user-friendly drag-and-drop interface.
#            2.   Enhancement to ggplot2: Acts as an enhancement to ggplot2, offering a simplified and intuitive interface for those less familiar with ggplot2 functions.
#            3.   Tableau-Like Drag and Drop: Introduces a Tableau-like drag-and-drop feature, making data visualization more accessible.
#            4.   Multiple Plot Types: Supports various plot types, including bar graphs, curves, scatter plots, and histograms.
#
#       *   Applications:
#            1.   Simplified ggplot2 Usage: Ideal for users finding ggplot2 functions challenging, offering a simplified alternative.
#            2.   Quick Exploratory Visualization: Facilitates rapid exploratory data visualization, allowing users to understand data patterns swiftly.
#            3.   Beginner-Friendly Data Analysis: Suited for beginners in R or data analysis, providing an accessible entry point to data visualization.
#            4.   Visualization Workshops and Teaching: Useful in visualization workshops or teaching environments to demonstrate concepts without extensive coding.
#
#  4.   **BioConductor :** When diving into Data Science, dealing with diverse data types is inevitable. In the health industry, especially working with genomic data, the Bioconductor library emerges as a valuable resource. Bioconductor, an open-source project, hosts a plethora of tools for analyzing biological data using R. Particularly useful for genomics, it offers a comprehensive set of packages for various tasks. Here are some key features and applications of BioConductor:
#
#       *   Features:
#            1.   Comprehensive Genomic Toolset: Offers a diverse range of tools for the analysis of biological data, with a focus on genomics.
#            2.   Open-Source Project: Bioconductor is an open-source project, fostering collaboration and continuous development in the field.
#            3.   Specialization in Genomic Analysis: Specifically designed for tasks related to genomic data, making it highly specialized and effective in this domain.
#            4.   Annotations and Data Packages: Provides tools for annotation and various data packages, enhancing the biological context of genomic analyses.
#
#       *   Applications:
#            1.   Genomic Data Visualization: Used for creating visualizations that help interpret complex genomic patterns.
#            2.   Biological Annotation: Supports the annotation of genomic features, adding valuable biological context to analyses.
#            3.   Normalization and Quality Control: Essential for ensuring data quality through normalization and pre-processing steps.
#            4.   Differential Expression Analysis: Crucial for identifying genes with significant expression differences in different experimental conditions.
#
#  5.   **Shiny :** Shiny is a widely recognized R package that becomes a Data Scientist's best friend when the goal is to share and visually explore data with others. It simplifies the creation of interactive web applications, allowing users to build standalone apps for web hosting, embed them in R Markdown documents, or construct dynamic dashboards. Shiny also offers flexibility for enhancing apps with CSS themes, htmlwidgets, and JavaScript actions. Here are some key features and applications of Shiny:
#
#       *   Features:
#            1.   Interactivity: Enables the creation of interactive web applications, enhancing user engagement.
#            2.   Web Hosting: Allows hosting of standalone Shiny apps on webpages for easy access and sharing.
#            3.   Embedding in Documents: Facilitates the embedding of Shiny apps within R Markdown documents for seamless integration.
#            4.   Dashboard Construction: Supports the construction of dynamic dashboards, providing a comprehensive view of data.
#
#       *   Applications:
#            1.   Data Exploration and Visualization: Ideal for creating interactive interfaces that enable users to explore and visualize data in real-time.
#            2.   Educational Purposes: Widely used in educational settings for teaching data science concepts through interactive demonstrations.
#            3.   Sharing Insights: Facilitates the sharing of data-driven insights with a broader audience in an accessible and interactive format.
#            4.   Dashboard Creation: Used for constructing dynamic dashboards that provide a consolidated view of key metrics and trends.
# 3.   Install 2 Libraries each for Python and R :-
#
# ```
# pip install Matplotlib
# pip install pandas
#
# ```
#
# ```
# install.packages("ggplot2")
# install.packages("dplyr")
# ```
#
#
# 4.   Perform simple experiments on the 2 identified libraries each for Python and R :-
#
#
# ```
# import matplotlib.pyplot as plt
#
# x = [1, 2, 3, 4, 5]
# y = [2, 4, 6, 8, 10]
#
# plt.plot(x, y, label='Simple Line Plot')
# plt.xlabel('X-axis')
# plt.ylabel('Y-axis')
# plt.title('Simple Line Plot using Matplotlib')
# plt.legend()
# plt.show()
# ```
#
# ```
# import pandas as pd
#
# data = {'Name': ['John', 'Jane', 'Bob', 'Alice'],
#         'Age': [25, 30, 22, 28],
#         'City': ['New York', 'London', 'Paris', 'Tokyo']}
#
# df = pd.DataFrame(data)
#
# print("Original DataFrame:")
# print(df)
#
# print("\nMean Age:", df['Age'].mean())
# print("\nCity counts:\n", df['City'].value_counts())
# ```
#
#
# ```
# library(ggplot2)
#
# x <- c(1, 2, 3, 4, 5)
# y <- c(2, 4, 6, 8, 10)
#
# data <- data.frame(x, y)
#
# ggplot(data, aes(x = x, y = y)) +
#   geom_line(color = "blue") +
#   labs(title = "Simple Line Plot using ggplot2", x = "X-axis", y = "Y-axis")
# ```
#
#
# ```
# library(dplyr)
#
# x <- c(1, 2, 3, 4, 5)
# y <- c(2, 4, 6, 8, 10)
#
# data <- data.frame(x, y)
#
# processed_data <- data %>%
#   mutate(y_squared = y^2) %>%
#   filter(y > 5)
#
# print(processed_data)
#
# ```
#
# ### **Conclusion :** In summary, Matplotlib and Pandas in Python, alongside ggplot2 and dplyr in R, are key libraries for data visualization and manipulation. Matplotlib and ggplot2 excel in creating diverse plots, while Pandas and dplyr simplify data tasks with intuitive features. The choice between Python and R depends on preferences, as both ecosystems offer strong solutions for data analysis.
